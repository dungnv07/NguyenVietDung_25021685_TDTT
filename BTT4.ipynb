# %%
#W4A1
n = int(input('Nhap so nguyen n: '))
a = 0
for i in range(1, n+1):
    a += i
print('Tong cac so nguyen tu 1 den n la:', a)
# Out:
# Nhap so nguyen n:  3
# Tong cac so nguyen tu 1 den n la:  6

# %%
#W4A8
a = int(input())
def reverse(a):
# Out:
#   Cell In[4], line 2
#     def reverse(a):
#                    ^
# IndentationError: expected an indented block
